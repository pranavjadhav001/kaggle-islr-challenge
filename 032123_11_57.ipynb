# %%
import warnings
warnings.simplefilter(action='ignore')
from focal_loss import SparseCategoricalFocalLoss
import pandas as pd
import tensorflow as tf
import glob
import json
import numpy as np
import random
import os
import tensorflow_io as tfio

# %%
def seed_it_all(seed=7):
    """ Attempt to be Reproducible """
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

seed_it_all()

# %%
ROWS_PER_FRAME = 543
def load_relevant_data_subset(pq_path):
    data_columns = ['x', 'y', 'z']
    data = pd.read_parquet(pq_path, columns=data_columns)
    n_frames = int(len(data) / ROWS_PER_FRAME)
    data = data.values.reshape(n_frames, ROWS_PER_FRAME, len(data_columns))
    return data.astype(np.float32)

#test_data  = load_relevant_data_subset('train_landmark_files/16069/100015657.parquet')

# %%
LIP = [
            61, 185, 40, 39, 37, 0, 267, 269, 270, 409,
            291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
            78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
            95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
]

# %%
class CFG:
    left_ROWS_per_frame = 21
    sequence_length = 20
    batch_size = 32
    face_ROWS_per_frame = 468
    lip_ROWS_per_frame = 40

labels  = json.load(open('sign_to_prediction_index_map.json','r'))
complete_df = pd.read_csv('train.csv')
from sklearn.model_selection import train_test_split
y = complete_df['sign']
train_df, test_df = train_test_split(complete_df, test_size=0.2,stratify=y)

# %%
def build_loader(with_labels=True):
    def load_video(video_path):
        #print('herer')
        video_df = tfio.IODataset.from_parquet(video_path)
        #video_df = pd.read_parquet(video_path, engine='pyarrow')
        #video_df.fillna(0,inplace=True)
        left_df = video_df[video_df.type=='left_hand']
        left_values = left_df[['x','y','z']].values
        left_values = left_values.reshape(-1,CFG.left_ROWS_per_frame,3)
        left_hand_array =  tf.image.resize(left_values, (CFG.sequence_length, CFG.left_ROWS_per_frame))
        right_df = video_df[video_df.type=='right_hand']
        right_values = right_df[['x','y','z']].values
        right_values = right_values.reshape(-1,CFG.left_ROWS_per_frame,3)
        right_hand_array =  tf.image.resize(right_values, (CFG.sequence_length, CFG.left_ROWS_per_frame))
        return [left_hand_array, right_hand_array]
    
    def load_video_with_labels(path, label):
        return load_video(path), labels[label]
    
    return load_video_with_labels if with_labels else load_video

# %%
class CustomData(tf.keras.utils.Sequence):
    def __init__(self,df,num_frames=20,batch_size=8,shuffle=True,\
                 labels_path='sign_to_prediction_index_map.json'):
        self.df = df
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.num_frames = num_frames
        self.labels  = json.load(open('sign_to_prediction_index_map.json','r'))
        self.on_epoch_end()
        
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.df))
        if self.shuffle:
            np.random.shuffle(self.indexes)
    
    def __getitem__(self,index):
        batches = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        left_hand_input = np.zeros(shape=(self.batch_size,self.num_frames,CFG.left_ROWS_per_frame,2))
        right_hand_input = np.zeros(shape=(self.batch_size,self.num_frames,CFG.left_ROWS_per_frame,2))
        lip_input = np.zeros(shape=(self.batch_size,self.num_frames,CFG.lip_ROWS_per_frame,2))
        labels = []
        for i,row_val in enumerate(batches):
            row = self.df.iloc[row_val]
            left_hand,right_hand,lip = self.load_video(row['path'])
            left_hand_input[i,:] = left_hand
            right_hand_input[i,:] = right_hand
            lip_input[i,:] = lip
            labels.append(self.labels[row['sign']])
        return [left_hand_input,right_hand_input,lip_input],np.asarray(labels)
            
    def load_video(self,video_path):
        video_df = pd.read_parquet(video_path, engine='pyarrow')
        video_df.dropna(inplace=True)
        left_df = video_df[video_df.type=='left_hand']
        left_values = left_df[['x','y']].values
        left_values = left_values.reshape(-1,CFG.left_ROWS_per_frame,2)
        if len(left_values)!=0:
            left_values[:,:,0] = (left_values[:,:,0]- np.min(left_values[:,:,0]))/(left_values[:,:,0].max()- left_values[:,:,0].min())
            left_values[:,:,1] = (left_values[:,:,1]- np.min(left_values[:,:,1]))/(left_values[:,:,1].max()- left_values[:,:,1].min())
            left_hand_array =  tf.image.resize(left_values, (CFG.sequence_length, CFG.left_ROWS_per_frame))
        else:
            left_hand_array =  tf.zeros(shape=(CFG.sequence_length, CFG.left_ROWS_per_frame,2),dtype=tf.float32)
        right_df = video_df[video_df.type=='right_hand']
        right_values = right_df[['x','y']].values
        right_values = right_values.reshape(-1,CFG.left_ROWS_per_frame,2)
        if len(right_values) != 0:
            right_values[:,:,0] = (right_values[:,:,0]- np.min(right_values[:,:,0]))/(right_values[:,:,0].max()- right_values[:,:,0].min())
            right_values[:,:,1] = (right_values[:,:,1]- np.min(right_values[:,:,1]))/(right_values[:,:,1].max()- right_values[:,:,1].min())
            right_hand_array =  tf.image.resize(right_values, (CFG.sequence_length, CFG.left_ROWS_per_frame))
        else:
            right_hand_array =  tf.zeros(shape=(CFG.sequence_length, CFG.left_ROWS_per_frame,2),dtype=tf.float32)
        face_df = video_df[video_df.type=='face']
        face_df = face_df[['x','y']].values
        face_df = face_df.reshape(-1,CFG.face_ROWS_per_frame,2)
        lip_values = face_df[:,LIP,:]
        if len(lip_values) != 0:
            lip_values[:,:,0] = (lip_values[:,:,0]- np.min(lip_values[:,:,0]))/(lip_values[:,:,0].max()- lip_values[:,:,0].min())
            lip_values[:,:,1] = (lip_values[:,:,1]- np.min(lip_values[:,:,1]))/(lip_values[:,:,1].max()- lip_values[:,:,1].min())
            lip_values_array =  tf.image.resize(lip_values, (CFG.sequence_length, CFG.lip_ROWS_per_frame))
        else:
            lip_values_array =  tf.zeros(shape=(CFG.sequence_length, CFG.lip_ROWS_per_frame,2),dtype=tf.float32)
        return left_hand_array, right_hand_array,lip_values_array
    
    def __len__(self):
        return len(self.df)//self.batch_size

# %%
train_datagen = CustomData(train_df,num_frames=CFG.sequence_length,batch_size=CFG.batch_size)
test_datagen = CustomData(test_df,num_frames=CFG.sequence_length,batch_size=CFG.batch_size)

# %%
def conv1d_lstm_block(inputs, filters):
    vector = tf.keras.layers.ConvLSTM1D(filters=32, kernel_size=3,return_sequences=True,padding='same',\
                                        kernel_regularizer=tf.keras.regularizers.L2(l2=0.01),\
                                        recurrent_regularizer=tf.keras.regularizers.L2(l2=0.01))(inputs)
    #vector = tf.keras.layers.Dropout(0.2)(vector)
    vector = tf.keras.layers.BatchNormalization(axis=-1)(vector)
    vector = tf.keras.layers.ConvLSTM1D(filters=64, kernel_size=3,return_sequences=True,padding='same',\
                                        kernel_regularizer=tf.keras.regularizers.L2(l2=0.01),\
                                        recurrent_regularizer=tf.keras.regularizers.L2(l2=0.01))(vector)
    #vector = tf.keras.layers.Dropout(0.2)(vector)
    vector = tf.keras.layers.BatchNormalization(axis=-1)(vector)
    vector = tf.keras.layers.ConvLSTM1D(filters=64, kernel_size=3,padding='same',\
                                       kernel_regularizer=tf.keras.regularizers.L2(l2=0.01),\
                                        recurrent_regularizer=tf.keras.regularizers.L2(l2=0.01))(vector)
    #vector = tf.keras.layers.Dropout(0.2)(vector)
    return vector

def get_model():
    input1 = tf.keras.Input((CFG.sequence_length, CFG.left_ROWS_per_frame, 2), dtype=tf.float32)
    input2 = tf.keras.Input((CFG.sequence_length, CFG.left_ROWS_per_frame, 2), dtype=tf.float32)
    input3 = tf.keras.Input((CFG.sequence_length, CFG.lip_ROWS_per_frame, 2), dtype=tf.float32)
    left_hand_vector = conv1d_lstm_block(input1, [64])
    right_hand_vector = conv1d_lstm_block(input2, [64])
    lip_vector = conv1d_lstm_block(input3, [64])
    vector = tf.keras.layers.Concatenate(axis=1)([left_hand_vector, right_hand_vector,lip_vector])
    vector = tf.keras.layers.Flatten()(vector)
    vector = tf.keras.layers.Dense(512, activation="relu")(vector)
    vector = tf.keras.layers.Dropout(0.3)(vector)
    output = tf.keras.layers.Dense(250, activation="softmax")(vector)
    model = tf.keras.Model(inputs=[input1,input2,input3], outputs=output)
    model.compile(tf.keras.optimizers.Adam(0.0000333),loss=SparseCategoricalFocalLoss(gamma=2), metrics="accuracy")
    return model

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 20, 21, 2)]  0           []
#
#  input_5 (InputLayer)           [(None, 20, 21, 2)]  0           []
#
#  input_6 (InputLayer)           [(None, 20, 40, 2)]  0           []
#
#  conv_lstm1d_9 (ConvLSTM1D)     (None, 20, 21, 32)   13184       ['input_4[0][0]']
#
#  conv_lstm1d_12 (ConvLSTM1D)    (None, 20, 21, 32)   13184       ['input_5[0][0]']
#
#  conv_lstm1d_15 (ConvLSTM1D)    (None, 20, 40, 32)   13184       ['input_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 20, 21, 32)  128         ['conv_lstm1d_9[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 20, 21, 32)  128         ['conv_lstm1d_12[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 20, 40, 32)  128         ['conv_lstm1d_15[0][0]']
#  ormalization)
#
#  conv_lstm1d_10 (ConvLSTM1D)    (None, 20, 21, 64)   73984       ['batch_normalization_6[0][0]']
#
#  conv_lstm1d_13 (ConvLSTM1D)    (None, 20, 21, 64)   73984       ['batch_normalization_8[0][0]']
#
#  conv_lstm1d_16 (ConvLSTM1D)    (None, 20, 40, 64)   73984       ['batch_normalization_10[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 20, 21, 64)  256         ['conv_lstm1d_10[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 20, 21, 64)  256         ['conv_lstm1d_13[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 20, 40, 64)  256         ['conv_lstm1d_16[0][0]']
#  ormalization)
#
#  conv_lstm1d_11 (ConvLSTM1D)    (None, 21, 64)       98560       ['batch_normalization_7[0][0]']
#
#  conv_lstm1d_14 (ConvLSTM1D)    (None, 21, 64)       98560       ['batch_normalization_9[0][0]']
#
#  conv_lstm1d_17 (ConvLSTM1D)    (None, 40, 64)       98560       ['batch_normalization_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 82, 64)       0           ['conv_lstm1d_11[0][0]',
#                                                                   'conv_lstm1d_14[0][0]',
#                                                                   'conv_lstm1d_17[0][0]']
#
#  flatten_1 (Flatten)            (None, 5248)         0           ['concatenate_1[0][0]']
#
#  dense_2 (Dense)                (None, 512)          2687488     ['flatten_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 250)          128250      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 3,374,074
# Trainable params: 3,373,498
# Non-trainable params: 576
# __________________________________________________________________________________________________

# %%
model = tf.keras.models.load_model('models/032123_11_57.h5')

# %%
file_name = "models/032123_11_57.h5"
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        file_name, 
        save_best_only=True, 
        monitor="val_accuracy",
        mode="max",
        verbose = 1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.1,mode='max',verbose=1,
                              patience=3, min_lr=0.000001)
]
model.fit(train_datagen,validation_data=test_datagen,\
          epochs=30, callbacks=callbacks)
# Out:
# Epoch 1/30
# 2361/2361 [==============================] - ETA: 0s - loss: 1.0843 - accuracy: 0.6838
# Epoch 1: val_accuracy improved from -inf to 0.62595, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1359s 570ms/step - loss: 1.0843 - accuracy: 0.6838 - val_loss: 1.4822 - val_accuracy: 0.6260 - lr: 3.3300e-04
# Epoch 2/30
# 2361/2361 [==============================] - ETA: 0s - loss: 1.0331 - accuracy: 0.6957
# Epoch 2: val_accuracy did not improve from 0.62595
# 2361/2361 [==============================] - 1374s 582ms/step - loss: 1.0331 - accuracy: 0.6957 - val_loss: 1.5130 - val_accuracy: 0.6196 - lr: 3.3300e-04
# Epoch 3/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.9807 - accuracy: 0.7084
# Epoch 3: val_accuracy did not improve from 0.62595
# 2361/2361 [==============================] - 1297s 549ms/step - loss: 0.9807 - accuracy: 0.7084 - val_loss: 1.5034 - val_accuracy: 0.6234 - lr: 3.3300e-04
# Epoch 4/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.9375 - accuracy: 0.7160
# Epoch 4: val_accuracy did not improve from 0.62595
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 3.330000035930425e-05.
# 2361/2361 [==============================] - 1297s 549ms/step - loss: 0.9375 - accuracy: 0.7160 - val_loss: 1.5321 - val_accuracy: 0.6187 - lr: 3.3300e-04
# Epoch 5/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.6745 - accuracy: 0.8010
# Epoch 5: val_accuracy improved from 0.62595 to 0.67389, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1297s 549ms/step - loss: 0.6745 - accuracy: 0.8010 - val_loss: 1.3519 - val_accuracy: 0.6739 - lr: 3.3300e-05
# Epoch 6/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.5929 - accuracy: 0.8254
# Epoch 6: val_accuracy improved from 0.67389 to 0.67405, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1298s 550ms/step - loss: 0.5929 - accuracy: 0.8254 - val_loss: 1.3330 - val_accuracy: 0.6740 - lr: 3.3300e-05
# Epoch 7/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.5593 - accuracy: 0.8306
# Epoch 7: val_accuracy improved from 0.67405 to 0.67722, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1299s 550ms/step - loss: 0.5593 - accuracy: 0.8306 - val_loss: 1.3211 - val_accuracy: 0.6772 - lr: 3.3300e-05
# Epoch 8/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.5072 - accuracy: 0.8498
# Epoch 8: val_accuracy did not improve from 0.67722
# 2361/2361 [==============================] - 1297s 549ms/step - loss: 0.5072 - accuracy: 0.8498 - val_loss: 1.3185 - val_accuracy: 0.6765 - lr: 3.3300e-05
# Epoch 9/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4852 - accuracy: 0.8555
# Epoch 9: val_accuracy did not improve from 0.67722
# 2361/2361 [==============================] - 1298s 550ms/step - loss: 0.4852 - accuracy: 0.8555 - val_loss: 1.3231 - val_accuracy: 0.6770 - lr: 3.3300e-05
# Epoch 10/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.8596
# Epoch 10: val_accuracy improved from 0.67722 to 0.68067, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1299s 550ms/step - loss: 0.4667 - accuracy: 0.8596 - val_loss: 1.3233 - val_accuracy: 0.6807 - lr: 3.3300e-05
# Epoch 11/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4504 - accuracy: 0.8648
# Epoch 11: val_accuracy did not improve from 0.68067
# 2361/2361 [==============================] - 1297s 549ms/step - loss: 0.4504 - accuracy: 0.8648 - val_loss: 1.3270 - val_accuracy: 0.6783 - lr: 3.3300e-05
# Epoch 12/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4332 - accuracy: 0.8695
# Epoch 12: val_accuracy did not improve from 0.68067
# 2361/2361 [==============================] - 1301s 551ms/step - loss: 0.4332 - accuracy: 0.8695 - val_loss: 1.3230 - val_accuracy: 0.6788 - lr: 3.3300e-05
# Epoch 13/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.8514
# Epoch 13: val_accuracy improved from 0.68067 to 0.68300, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1299s 550ms/step - loss: 0.4656 - accuracy: 0.8514 - val_loss: 1.3114 - val_accuracy: 0.6830 - lr: 3.3300e-05
# Epoch 14/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4554 - accuracy: 0.8545
# Epoch 14: val_accuracy did not improve from 0.68300
# 2361/2361 [==============================] - 1302s 551ms/step - loss: 0.4554 - accuracy: 0.8545 - val_loss: 1.3186 - val_accuracy: 0.6783 - lr: 3.3300e-05
# Epoch 15/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4454 - accuracy: 0.8578
# Epoch 15: val_accuracy did not improve from 0.68300
# 2361/2361 [==============================] - 1304s 552ms/step - loss: 0.4454 - accuracy: 0.8578 - val_loss: 1.3101 - val_accuracy: 0.6768 - lr: 3.3300e-05
# Epoch 16/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8591
# Epoch 16: val_accuracy did not improve from 0.68300
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.3299998904112727e-06.
# 2361/2361 [==============================] - 1305s 553ms/step - loss: 0.4356 - accuracy: 0.8591 - val_loss: 1.3243 - val_accuracy: 0.6790 - lr: 3.3300e-05
# Epoch 17/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4056 - accuracy: 0.8726
# Epoch 17: val_accuracy did not improve from 0.68300
# 2361/2361 [==============================] - 1304s 552ms/step - loss: 0.4056 - accuracy: 0.8726 - val_loss: 1.3098 - val_accuracy: 0.6818 - lr: 3.3300e-06
# Epoch 18/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.4047 - accuracy: 0.8723
# Epoch 18: val_accuracy did not improve from 0.68300
# 2361/2361 [==============================] - 1306s 553ms/step - loss: 0.4047 - accuracy: 0.8723 - val_loss: 1.3085 - val_accuracy: 0.6825 - lr: 3.3300e-06
# Epoch 19/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8741
# Epoch 19: val_accuracy improved from 0.68300 to 0.68353, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1304s 552ms/step - loss: 0.3998 - accuracy: 0.8741 - val_loss: 1.3078 - val_accuracy: 0.6835 - lr: 3.3300e-06
# Epoch 20/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.3970 - accuracy: 0.8749
# Epoch 20: val_accuracy did not improve from 0.68353
# 2361/2361 [==============================] - 1314s 557ms/step - loss: 0.3970 - accuracy: 0.8749 - val_loss: 1.3069 - val_accuracy: 0.6833 - lr: 3.3300e-06
# Epoch 21/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8750
# Epoch 21: val_accuracy improved from 0.68353 to 0.68374, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1311s 555ms/step - loss: 0.3971 - accuracy: 0.8750 - val_loss: 1.3093 - val_accuracy: 0.6837 - lr: 3.3300e-06
# Epoch 22/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8752
# Epoch 22: val_accuracy improved from 0.68374 to 0.68406, saving model to models/032123_11_57.h5
# 2361/2361 [==============================] - 1304s 552ms/step - loss: 0.3957 - accuracy: 0.8752 - val_loss: 1.3080 - val_accuracy: 0.6841 - lr: 3.3300e-06
# Epoch 23/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.3918 - accuracy: 0.8775
# Epoch 23: val_accuracy did not improve from 0.68406
# 2361/2361 [==============================] - 1302s 552ms/step - loss: 0.3918 - accuracy: 0.8775 - val_loss: 1.3087 - val_accuracy: 0.6833 - lr: 3.3300e-06
# Epoch 24/30
# 2361/2361 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8769

# %%
model.save('models/030523_00_09.h5')
